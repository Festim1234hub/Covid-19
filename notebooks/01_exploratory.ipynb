# %% [markdown]
# # Eksplorimi Fillestar i Dataset-it
#
# Dataset: Our World in Data — COVID-19
# Filtrim: 20 vende evropiane

# %% [markdown]
# ## 1. Ngarkimi i Bibliotekave

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

pd.set_option('display.max_columns', None)
pd.set_option('display.float_format', '{:.2f}'.format)

# %% [markdown]
# ## 2. Ngarkimi dhe Filtrimi i Dataset-it

# %%
COUNTRIES = [
    'Albania', 'Kosovo', 'North Macedonia', 'Bosnia and Herzegovina',
    'Montenegro', 'Croatia', 'Slovenia', 'Bulgaria', 'Romania',
    'Hungary', 'Austria', 'Italy', 'Greece', 'Germany',
    'France', 'Spain', 'Portugal', 'Poland', 'Czechia', 'Switzerland'
]

COLUMNS = [
    'location', 'date', 'total_cases', 'total_deaths',
    'total_vaccinations_per_hundred', 'gdp_per_capita', 'population'
]

df_raw = pd.read_csv('../data/raw/covid_data.csv', usecols=COLUMNS, parse_dates=['date'])
df = df_raw[df_raw['location'].isin(COUNTRIES)].copy()
df = df.sort_values(['location', 'date']).reset_index(drop=True)

print(f'Rreshtat: {df.shape[0]:,}')
print(f'Kolonat: {df.shape[1]}')
print(f'Vendet: {df["location"].nunique()}')
print(f'Periudha: {df["date"].min().date()} → {df["date"].max().date()}')

# %% [markdown]
# ## 3. Shembull i të Dhënave

# %%
df.head(10)

# %% [markdown]
# ## 4. Tipet e Kolonave

# %%
df.dtypes

# %% [markdown]
# ## 5. Vlerat Mungese (NaN)

# %%
nan_df = pd.DataFrame({
    'NaN count': df.isnull().sum(),
    'NaN %': (df.isnull().mean() * 100).round(2)
})
nan_df[nan_df['NaN count'] > 0]

# %% [markdown]
# ## 6. Statistikat Bazë të Dataset-it të Papërpunuar

# %%
df.describe().round(2)
